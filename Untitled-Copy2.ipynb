# %%
import pytesseract
from imutils.video import VideoStream
import imutils

# %%
import cv2
import matplotlib.pyplot as plt

# %%
pytesseract.pytesseract.tesseract_cmd=r'C:\\Program Files\\Tesseract-OCR\\tesseract.exe'

# %%
img=cv2.imread('img.png')

# %%
plt.imshow(img)

# %%
img2char=pytesseract.image_to_string(img)

# %%
imgbox=pytesseract.image_to_boxes(img)

# %%
print(img2char)
# Out:
# Deep Learning and
# Computer Vision
# Tutorials

# %%
print(imgbox)
# Out:
# D 25 113 34 126 0
# e 31 111 40 126 0
# e 35 113 52 123 0
# p 54 111 62 123 0
# L 72 114 79 126 0
# e 79 113 88 123 0
# a 88 113 96 123 0
# r 97 114 102 123 0
# n 104 114 111 123 0
# i 113 114 115 123 0
# n 117 114 125 123 0
# g 126 110 134 123 0
# a 140 113 147 123 0
# n 149 114 156 123 0
# d 158 113 166 126 0
# C 24 94 33 106 0
# o 34 94 43 103 0
# m 44 94 57 103 0
# p 51 91 62 106 0
# u 59 91 67 103 0
# t 68 94 76 103 0
# e 78 94 83 105 0
# r 84 94 98 103 0
# V 103 94 112 106 0
# i 114 94 116 106 0
# s 117 94 124 103 0
# i 125 94 127 106 0
# o 128 94 137 103 0
# n 139 94 146 103 0
# T 24 72 33 85 0
# u 29 72 36 85 0
# t 32 72 40 81 0
# o 41 72 47 83 0
# r 47 72 56 82 0
# i 58 72 63 82 0
# a 64 72 66 81 0
# l 67 72 79 85 0
# s 80 72 86 82 0

# %%
imgH,IMgW,_=img.shape

for boxes in imgbox.splitlines():
    boxes=boxes.split(' ')
    x,y,w,h=int(boxes[1]),int(boxes[2]),int(boxes[3]),int(boxes[4])
    cv2.rectangle(img,(x,imgH-y),(w,imgH-h),(0,0,255),3)

# %%
plt.imshow(cv2.cvtColor(img,cv2.COLOR_BGR2RGB))

# %%
x=open("string.txt",'w')

# %%
print(img2char,file=x)
x.close()

# %%
font_scale=1.5
font=cv2.FONT_HERSHEY_PLAIN

cap=VideoStream('img.png').start()
# if not cap.isOpened():
#     cap=cv2.VideoCapture(1)
# if not cap.isOpened():
#     raise IOError("Cannot Open the Webcam")
f=0
while True:
    frame=cap.read()
#     frame=imutils.resize(frame,width=400)
#     print(frame)
    imgH,imgW=frame.shape[:2]
    x1,y1,w1,h1=0,0,imgH,imgW
    imgchar=pytesseract.image_to_string(frame)
    print(imgchar)
    imgbox=pytesseract.image_to_boxes(frame)
    for boxes in imgbox.splitlines():
        boxes=boxes.split(' ')
        x,y,w,h=int(boxes[1]),int(boxes[2]),int(boxes[3]),int(boxes[4])
        cv2.rectangle(frame,(x,imgH-y),(w,imgH-h),(0,0,255),3)
    cv2.putText(frame,imgchar,(x1+int(w1/50),y1+int(h1/50)),cv2.FONT_HERSHEY_SIMPLEX,0.7,(0,0,255),2)
    font=cv2.FONT_HERSHEY_SIMPLEX

    cv2.imshow('Hello',frame)
    if cv2.waitKey(2) & 0xFF == ord('q'):
        break
cap.stop()
cap.stream.release()
cv2.destroyAllWindows()
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# <ipython-input-6-dc7134041085> in <module>
#      12 #     frame=imutils.resize(frame,width=400)
#      13 #     print(frame)
# ---> 14     imgH,imgW=frame.shape[:2]
#      15     x1,y1,w1,h1=0,0,imgH,imgW
#      16     imgchar=pytesseract.image_to_string(frame)
#
# AttributeError: 'NoneType' object has no attribute 'shape'

# %%
cap.stream.release()
